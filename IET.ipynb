# %% [markdown]
# # Urban Air Quality Monitoring & Health-Risk Prediction
# This notebook runs the project code from the folder in Google Colab.

# %%
import os

# !pip install -q -r /content/requirements.txt

# %%
# !python /content/air_quality_ml.py
# Out:
# === DATASET ===
# Shape: (500, 12)
#         PM2.5        PM10        NO2  ...     Pressure         AQI  AirQuality
# 0   96.383384  179.107766  75.005604  ...   991.009001  150.585832        Poor
# 1  127.076652  204.480313  80.976004  ...  1015.377984  162.188213        Poor
# 2   85.726114  157.178961  80.706014  ...  1009.944140  113.980127        Poor
# 3   77.619083  119.383527  55.125278  ...  1005.488460  102.509363        Poor
# 4  137.034920  230.104538  89.465988  ...  1000.270517  182.920274        Poor
#
# [5 rows x 12 columns]
#
# Missing values:
# PM2.5          0
# PM10           0
# NO2            0
# SO2            0
# CO             0
# O3             0
# Temperature    0
# Humidity       0
# WindSpeed      0
# Pressure       0
# AQI            0
# dtype: int64
#
# Statistics:
#             PM2.5        PM10         NO2  ...   WindSpeed     Pressure         AQI
# count  500.000000  500.000000  500.000000  ...  500.000000   500.000000  500.000000
# ...

# %%
import os
from IPython.display import display, Image

print('Generated result files:')
for root, dirs, files in os.walk('results'):
    for f in files:
        print(os.path.join(root, f))
# Out:
# Generated result files:
# results/lwr_results.csv
# results/class_summary.csv
# results/model_comparison.csv
# results/figures/cm_mlp.png
# results/figures/cm_ga_decision_tree.png
# results/figures/03_pm25_vs_aqi.png
# results/figures/cm_naive_bayes.png
# results/figures/05_class_distribution.png
# results/figures/07_knn_validation_curve.png
# results/figures/02_aqi_pattern.png
# results/figures/cm_knn.png
# results/figures/cm_decision_tree.png
# results/figures/01_pm25_distribution.png
# results/figures/06_decision_tree.png
# results/figures/04_correlation_heatmap.png

# %% [markdown]
# ### `/content/air_quality.csv`

# %%
with open('/content/air_quality.csv', 'r') as f:
    print(f.read())
# Out:
# PM2.5,PM10,NO2,SO2,CO,O3,Temperature,Humidity,WindSpeed,Pressure,AQI
# 96.38338397335217,179.10776581955585,75.00560433718499,12.951870506668001,1.8134509425463974,40.093722123375265,24.829444302351448,51.44776194164239,2.1337969950714677,991.0090006408932,150.58583216654193
# 127.07665150615703,204.48031275814824,80.9760042836836,28.376841802548707,1.7601592637476207,49.75760720467366,28.475389145304188,53.97105107359502,1.3029477887758896,1015.3779835293755,162.18821311496862
# 85.72611429349729,157.17896117845163,80.70601375029042,11.191201524603752,1.8762690491849185,62.48804972936395,26.54835210411112,50.45272905107262,4.51161522565749,1009.9441404907856,113.98012738125692
# 77.61908316602523,119.38352734885734,55.12527835172955,25.039569468628088,1.0600799472637723,84.72510011079473,33.009478243032206,69.85197576425915,3.779198948353904,1005.4884603620172,102.50936345606422
# ...

# %% [markdown]
# ### `/content/air_quality_ml.py`

# %%
with open('/content/air_quality_ml.py', 'r') as f:
    print(f.read())
# Out:
# """
# ITA0614 – Machine Learning
# Intelligent Urban Air Quality Monitoring and Health-Risk Prediction System
#
# Run:
#     python air_quality_ml.py
#
# Input:
#     air_quality.csv
#
# Note:
# The included CSV is synthetic/demo data created to match the assignment schema.
# For final submission, replace it with the exact real dataset selected for the report
# and document its source/license.
# """
#
# import os
# import time
# import random
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# from collections import Counter
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler, LabelEncoder
# from sklearn.tree import DecisionTreeClassifier, plot_tree
# from sklearn.naive_bayes import GaussianNB
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import (
#     accuracy_score, precision_score, recall_score, f1_score,
#     classification_report, confusion_matrix,
# ...

# %% [markdown]
# ### `/content/README.md`

# %%
with open('/content/README.md', 'r') as f:
    print(f.read())
# Out:
# # ITA0614 Air Quality ML Project
#
# ## Files
# - `air_quality.csv` — synthetic/demo dataset matching the assignment columns.
# - `air_quality_ml.py` — complete runnable program covering preprocessing, EDA, Candidate-Elimination demo, Decision Tree, Gaussian Naive Bayes, first-principles KNN, first-principles LWR, first-principles MLP Back Propagation, GA feature selection, evaluation and warning logic.
# - `requirements.txt` — Python packages.
#
# ## Important
# The assignment document requires a real air-quality dataset and its exact source/license to be documented. The included CSV is only a demo dataset so the code can run immediately. Replace it with the real dataset before final submission.
#
# ## Run in VS Code
# 1. Install Python 3.10+.
# 2. Open this folder in VS Code.
# 3. Open Terminal.
# 4. Run:
#    `pip install -r requirements.txt`
# 5. Run:
#    `python air_quality_ml.py`
#
# ## Outputs
# The program creates:
# - `results/class_summary.csv`
# ...

# %% [markdown]
# ### `/content/requirements.txt`

# %%
with open('/content/requirements.txt', 'r') as f:
    print(f.read())
# Out:
# numpy
# pandas
# matplotlib
# scikit-learn
# python-docx

# %% [markdown]
# ### Generated Figures

# %%
from IPython.display import Image, display

image_files = [
    'cm_mlp.png',
    'cm_ga_decision_tree.png',
    '03_pm25_vs_aqi.png',
    'cm_naive_bayes.png',
    '05_class_distribution.png',
    '07_knn_validation_curve.png',
    '02_aqi_pattern.png',
    'cm_knn.png',
    'cm_decision_tree.png',
    '01_pm25_distribution.png',
    '06_decision_tree.png',
    '04_correlation_heatmap.png'
]

for img_file in image_files:
    print(f"\n#### {img_file}")
    display(Image(filename=f'/content/results/figures/{img_file}'))
# Out:
# #### cm_mlp.png
# #### cm_ga_decision_tree.png
# #### 03_pm25_vs_aqi.png
# #### cm_naive_bayes.png
# #### 05_class_distribution.png
# #### 07_knn_validation_curve.png
# #### 02_aqi_pattern.png
# #### cm_knn.png
# #### cm_decision_tree.png
# #### 01_pm25_distribution.png
# #### 06_decision_tree.png
# #### 04_correlation_heatmap.png

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/cm_mlp.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/cm_ga_decision_tree.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/03_pm25_vs_aqi.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/cm_naive_bayes.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/05_class_distribution.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/07_knn_validation_curve.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/02_aqi_pattern.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/cm_knn.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/cm_decision_tree.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/01_pm25_distribution.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/06_decision_tree.png'))

# %%
from IPython.display import Image, display
display(Image(filename='/content/results/figures/04_correlation_heatmap.png'))
